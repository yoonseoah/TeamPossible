# %% [markdown]
# #### **오디오 데이터 추출**

# %% [markdown]
# ##### **사전 준비**

# %% [markdown]
# 라이브러리 import

# %%
import os
import torch
import torchaudio
import numpy as np
from transformers import ASTFeatureExtractor, ASTModel

# %% [markdown]
# 사전 학습 모델 import

# %%
pretrained_model = "MIT/ast-finetuned-audioset-10-10-0.4593"
feature_extractor = ASTFeatureExtractor.from_pretrained(pretrained_model)
model = ASTModel.from_pretrained(pretrained_model)

# %% [markdown]
# GPU 사용 확인 및 모델 설정

# %%
print(torch.cuda.is_available()) 
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3070 Ti Laptop GPU

# %%
model.eval() # 모델 추론 모드로 설정
model.cuda() # GPU 사용
# Out:
# ASTModel(
#   (embeddings): ASTEmbeddings(
#     (patch_embeddings): ASTPatchEmbeddings(
#       (projection): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): ASTEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x ASTLayer(
#         (attention): ASTAttention(
#           (attention): ASTSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (output): ASTSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (intermediate): ASTIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ASTOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#         (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
# )

# %% [markdown]
# ##### **1. .wav 파일 로드**

# %%
import soundfile as sf

def load_audio(path):
    waveform, sr = sf.read(path, dtype='float32')
    waveform = torch.from_numpy(waveform).squeeze() # [T]
    return waveform, sr

# %% [markdown]
# ##### **2. Spectrogram 변환**

# %%
def extract_spectrogram(waveform, sr=16000):
    inputs = feature_extractor(
        waveform,
        sampling_rate=sr,
        return_tensors="pt"
    )
    return {k: v.cuda() for k, v in inputs.items()}

# %% [markdown]
# ##### **3. ASTModel에 입력 & 4. [CLS] 임베딩 추출**

# %%
@torch.no_grad()
def forward_ast(inputs):
    outputs = model(**inputs)
    cls_embedding = outputs.last_hidden_state[:, 0, :]  # shape: [1, 768]
    return cls_embedding

# %% [markdown]
# ##### **5. 128-dim Linear Projection & 6. .npy 저장**

# %%
projector = torch.nn.Linear(768, 128).cuda()
projector.eval()

def save_feature(cls_embedding, save_path):
    feature_128 = projector(cls_embedding)  # shape: [1, 128]
    feature_128 = feature_128.squeeze(0).detach().cpu().numpy()  # shape: [128]
    np.save(save_path, feature_128)
    print(f"Saved: {save_path}")

# %% [markdown]
# ##### **테스트**

# %%
audio_path = r"D:\Audio\training\barking\18frames\getty-dog-barks-video-id513564656_7.wav"

#1
waveform, sr = load_audio(audio_path)
print(waveform)
print(waveform.shape)
print(len(waveform))
# Out:
# tensor([0.0847, 0.1185, 0.0897,  ..., 0.0000, 0.0000, 0.0000])
# torch.Size([48298])
# 48298

# %%
# 2
inputs = extract_spectrogram(waveform)                
print(inputs)
inputs["input_values"].shape
# Out:
# {'input_values': tensor([[[-0.3234, -0.5673, -0.1904,  ...,  0.0113, -0.0695, -0.0433],
#          [-0.4913, -0.4756, -0.0988,  ...,  0.0318,  0.0552,  0.0092],
#          [-0.4133, -0.4458, -0.0690,  ...,  0.0063,  0.1096,  0.1186],
#          ...,
#          [ 0.4670,  0.4670,  0.4670,  ...,  0.4670,  0.4670,  0.4670],
#          [ 0.4670,  0.4670,  0.4670,  ...,  0.4670,  0.4670,  0.4670],
#           7.7884e-01,  1.1480e+00, -1.0054e-02,  1.1252e+00, -1.8336e+00,
#          -1.3573e+00, -1.0960e+00,  6.5714e-01, -3.4106e-02, -7.3551e-01,
#           8.5821e-01,  5.6013e-01, -1.2992e+00,  3.5806e-01,  2.6465e-01,
#          -8.9083e-01, -2.2786e+00,  4.7303e-01,  1.5868e+00, -4.6878e-01,
#           5.7428e-02, -1.5916e+00,  2.3488e+00,  2.6721e+00, -1.1024e+00,
#          -2.9123e+00, -8.5347e-01,  1.7739e+00,  1.0433e+00,  5.9512e-01,
#          -2.0651e+00,  7.0530e-01,  9.5631e-01,  4.9902e-01,  5.6443e-01,
#           6.3578e-01,  2.9608e+00, -3.3059e-01,  7.7062e-01, -8.7790e-01,
#          -1.0405e-02, -2.0336e-01,  1.0957e+00, -2.1673e-01, -6.7156e-01,
#          -3.9713e-01,  1.2563e+00,  1.5809e+00,  1.2155e+00, -1.2234e-01,
#           1.0253e-01, -1.0398e+00, -1.8256e-01,  2.7696e-01, -5.5109e-01,
#           2.4120e+00,  2.0630e+00,  3.4432e-01,  7.4009e-01, -1.2946e+00,
#           4.2965e-01,  7.0451e-01,  1.6297e+00,  9.6153e-01, -2.3511e+00,
#          -4.6914e-01,  2.2504e-01,  3.5277e-01,  1.3259e+00,  1.7577e+00,
#           8.3944e-01,  8.9591e-02,  5.8240e-01,  9.9276e-01, -1.4247e-02,
#          -9.2183e-01,  1.2241e+00,  1.6042e+00,  1.8113e+00,  1.8812e-01,
#          -6.8541e-01, -7.0610e-01,  1.5490e-01, -7.7937e-01, -3.8711e-02,
#          -5.8617e-01, -2.5402e+00,  2.6853e+00, -1.4278e+00, -2.6264e-01,
#          -6.0078e-01, -1.1160e+00, -2.5100e-01,  1.3497e+00, -4.5923e-01,
#           4.8575e-01, -6.5210e-01, -2.3734e+00,  1.3287e+00, -2.1639e-01,
#          -3.0319e-01, -1.4789e+00, -7.5658e-01,  2.0450e+00,  3.4728e-01,
#          -7.1403e-01,  2.3870e-01,  3.5188e-01,  7.4009e-01, -1.1813e+00,
#           2.2142e+00, -2.3314e-01,  8.7664e-03,  6.9245e-01, -7.6533e-01,
#          -1.0900e+00, -4.4040e-01, -1.1375e-01,  2.0898e+00, -4.1661e-01,
#          -1.9190e-01,  2.3104e+00,  2.6872e-02,  1.2088e-03, -1.2168e+00,
#           2.6588e-02,  1.6192e+00, -1.8321e+00,  1.2812e+00, -1.7032e+00,
#          -1.6083e+00, -1.1690e+00,  1.3249e+00]], device='cuda:0')
# torch.Size([1, 768])

# %%
save_path = r"D:\테스트\test.npy"
save_feature(cls_emb, save_path)
# Out:
# Saved: D:\테스트\test.npy

# %%
loaded = np.load("D:/테스트/test.npy")
print(loaded.shape)    # (128,)
print(loaded[:10])
# Out:
# (128,)
# [-1.0215124e+00 -2.5498366e-01  1.1035247e+00  9.7031170e-01
#   4.6447691e-02 -9.1116971e-01 -2.5522530e-02  8.0757588e-04
#  -3.6133379e-01 -3.5749629e-01]
